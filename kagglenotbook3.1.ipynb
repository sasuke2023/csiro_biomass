# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/csiro-biomasszipdataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/csiro-biomasszipdataset/sample_submission.csv
# /kaggle/input/csiro-biomasszipdataset/train.csv
# /kaggle/input/csiro-biomasszipdataset/test.csv
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2099464826.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2037861084.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1211362607.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1853508321.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID193102215.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID698608346.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1859251563.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1880764911.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID853954911.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1403107574.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1781353117.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID384648061.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1563418511.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2125100696.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID482555369.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID638711343.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID779628955.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1876271942.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1692894460.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID746335827.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1136169672.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1471216911.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID846154859.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1294770420.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1183807388.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID423506847.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1889150649.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1140993511.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1413758094.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1545077474.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID95050718.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID528010569.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1645161155.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID786365141.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID896386823.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1025234388.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID663006174.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1509266870.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1496750796.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID471758347.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID740402124.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1624268863.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1098771283.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID710341728.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2086966681.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1573329652.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID54128926.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID50027657.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1559189397.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID290369222.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1590632667.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID552040066.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID488873801.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID363069566.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1839139621.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1131079710.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2010625680.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID152157478.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1357758282.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1498398599.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID679913293.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID697718693.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID4464212.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1275072698.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1579942839.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID799079114.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1415329644.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1510574031.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1078930021.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1456861072.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID930534670.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID13162390.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID567744300.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID344618040.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID566966892.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1437386574.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID667059550.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID72895391.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1193692654.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1386202352.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID871463897.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2096636211.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2003438517.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID21377800.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID230058600.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1753847361.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1512751450.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID12390962.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1746343319.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID978026131.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID383231615.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID146920896.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1036339023.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1168534540.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1859792585.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1251029854.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1113329413.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1874904894.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1671844336.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1831254380.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1103883611.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID797502182.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1784585001.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1058383417.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1488408526.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID429799190.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1291116815.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1516374298.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1618597318.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1345375788.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID686797154.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1139866256.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1149598723.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID212206250.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID112966473.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1540480250.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID544444725.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1513184765.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID668330410.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1444674500.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1962379474.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID605134229.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID914754166.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID354528442.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID950496197.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1395011773.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1357768767.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID210865340.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID936984905.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1976436386.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1215977190.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID803479541.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1244346858.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID158170916.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1208644039.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1314135397.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1012260530.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1053972079.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID656251220.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1084819986.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1337107565.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1268934251.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID617132135.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1472525822.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID668475812.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID681680726.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1476045099.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1570190541.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1403078396.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2030696575.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1782608354.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID194823383.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID196516535.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID212206832.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1638922597.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1457700382.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1989506559.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID789169173.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1634731537.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1428837636.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2006686196.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID885388135.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1789853061.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1655778545.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID697059386.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID121331988.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2099742797.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID342818398.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID317990700.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID706288721.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1159071020.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID755710743.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1254829053.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID475010202.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1693880739.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1894998379.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID48303557.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1385921939.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID147528735.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID407646960.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1035947949.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1119761112.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1988033238.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1857489997.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID742198710.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID588120964.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID431471530.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID353424190.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID380752847.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2069766023.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID600602588.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID560946727.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID808079729.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1217108125.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1623964968.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID980878870.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID793526563.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID397994621.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID975115267.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1237349078.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID684383343.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID866684633.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1665142816.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2048645043.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1953171547.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1451025862.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID71885430.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID307060225.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID969218269.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID980538882.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1028611175.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID670276799.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2002797732.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1374789439.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID473494649.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1993907137.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1962197151.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID828217731.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID972274220.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1954669045.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1354190372.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1458758610.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID40849327.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1952813879.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID572336285.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1473228876.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1963715583.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1463690813.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1899025384.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID386216505.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1789265307.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID315357834.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2089023774.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID520514019.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1970522802.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1139918758.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1051144034.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1370004842.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID761508093.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2052993274.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1277756619.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID6269659.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1574125908.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID135365668.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1182523622.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID554314721.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1049634115.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1127246618.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID900012207.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID574213894.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID415656958.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID61833032.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2053315094.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID550623196.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID657448172.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1675365449.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2014192906.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID162394992.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID968643034.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID684062938.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID802547515.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID294150104.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1618145129.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID956512130.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID142751858.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID325799913.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID443091455.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID661372352.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1062837331.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID498304885.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID187238869.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1450399782.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2056023629.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID576621307.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1199150612.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1411613934.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID105271783.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1703304524.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID875119737.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1176292407.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1729002155.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2091439402.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID576137678.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1946311744.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1982662138.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID983582017.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID661817669.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID753699705.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1789834546.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID529933668.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID490139972.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID743847993.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID7850481.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1088965591.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID629980789.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1119739385.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1477176296.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1113121340.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2131261930.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2145635095.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1414371018.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1148666289.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID839432753.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID157479394.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1761544403.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID846984946.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID751517087.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID577112774.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID353997899.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID748979397.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1070112260.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1108283583.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1868719645.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1980675327.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1163061745.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1148528732.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID534966093.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1717006117.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1953218650.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID633775166.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID808093827.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1997244125.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1920959057.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1948354837.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID364856705.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID249042826.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID332742639.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1680597197.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1421714468.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID905397692.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1782509721.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID141370843.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2056982009.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID94564238.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID8209776.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID908524512.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID610397481.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID750820644.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1515990019.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1547945326.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID587125778.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1620371305.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1474775613.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID545360459.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1783499590.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1249094008.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1525817840.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID227847873.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1052620238.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1888700589.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID2052442675.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID963903358.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1121692672.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1343327476.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID1667778338.jpg
# /kaggle/input/csiro-biomasszipdataset/train/ID257822026.jpg

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/csiro-biomasszipdataset/sample_submission.csv')
df.head()
# Out:
#                     sample_id  target
# 0  ID1001187975__Dry_Clover_g     0.0
# 1    ID1001187975__Dry_Dead_g     0.0
# 2   ID1001187975__Dry_Green_g     0.0
# 3   ID1001187975__Dry_Total_g     0.0
# 4         ID1001187975__GDM_g     0.0

# %%
df = pd.read_csv('/kaggle/input/csiro-biomasszipdataset/train.csv')
df.head()
# Out:
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750

# %%
df = pd.read_csv('/kaggle/input/csiro-biomasszipdataset/test.csv')
df.head()
# Out:
#                     sample_id             image_path   target_name
# 0  ID1001187975__Dry_Clover_g  test/ID1001187975.jpg  Dry_Clover_g
# 1    ID1001187975__Dry_Dead_g  test/ID1001187975.jpg    Dry_Dead_g
# 2   ID1001187975__Dry_Green_g  test/ID1001187975.jpg   Dry_Green_g
# 3   ID1001187975__Dry_Total_g  test/ID1001187975.jpg   Dry_Total_g
# 4         ID1001187975__GDM_g  test/ID1001187975.jpg         GDM_g

# %%
import os
import pandas as pd

def load_or_make_data():
    # Fixed Kaggle dataset paths
    TRAIN_PATH = "/kaggle/input/csiro-biomasszipdataset/train.csv"
    TEST_PATH  = "/kaggle/input/csiro-biomasszipdataset/test.csv"

    # Check if train.csv exists
    if not os.path.exists(TRAIN_PATH):
        raise FileNotFoundError(f"❌ train.csv NOT found at: {TRAIN_PATH}\n"
                                f"Please verify the dataset is added in Kaggle Notebook.")

    # Check if test.csv exists
    if not os.path.exists(TEST_PATH):
        raise FileNotFoundError(f"❌ test.csv NOT found at: {TEST_PATH}\n"
                                f"Please verify the dataset is added in Kaggle Notebook.")

    print(f"✅ Loading TRAIN data from: {TRAIN_PATH}")
    train_df = pd.read_csv(TRAIN_PATH)

    print(f"✅ Loading TEST data from: {TEST_PATH}")
    test_df = pd.read_csv(TEST_PATH)

    # Return ONLY real competition data
    return train_df, test_df

# %%
train_df, test_df = load_or_make_data()

train_df.head(), test_df.head()
# Out:
# ✅ Loading TRAIN data from: /kaggle/input/csiro-biomasszipdataset/train.csv
# ✅ Loading TEST data from: /kaggle/input/csiro-biomasszipdataset/test.csv
# (                    sample_id              image_path Sampling_Date State  \
#  0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
#  1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
#  2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
#  3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
#  4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#             Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target
#  0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
#  1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
#  2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
#  3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
#  4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750  ,
#                      sample_id             image_path   target_name
#  0  ID1001187975__Dry_Clover_g  test/ID1001187975.jpg  Dry_Clover_g
#  1    ID1001187975__Dry_Dead_g  test/ID1001187975.jpg    Dry_Dead_g
#  2   ID1001187975__Dry_Green_g  test/ID1001187975.jpg   Dry_Green_g
#  3   ID1001187975__Dry_Total_g  test/ID1001187975.jpg   Dry_Total_g
#  4         ID1001187975__GDM_g  test/ID1001187975.jpg         GDM_g)

# %%
# ============================================================
# 1. Imports & Config
# ============================================================
import os
import gc
import numpy as np
import pandas as pd

from tqdm import tqdm

# ML / preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score
from sklearn.ensemble import VotingRegressor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

# PyTorch / CNN
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as T
import torchvision.models as models

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)

print("✅ Imports done. Torch CUDA available:", torch.cuda.is_available())
# Out:
# ✅ Imports done. Torch CUDA available: False

# %%
# ============================================================
# 2. Load REAL competition data (NO synthetic data)
# ============================================================
def load_data():
    TRAIN_PATH = "/kaggle/input/csiro-biomasszipdataset/train.csv"
    TEST_PATH  = "/kaggle/input/csiro-biomasszipdataset/test.csv"

    if not os.path.exists(TRAIN_PATH):
        raise FileNotFoundError(f"❌ train.csv not found at: {TRAIN_PATH}")
    if not os.path.exists(TEST_PATH):
        raise FileNotFoundError(f"❌ test.csv not found at: {TEST_PATH}")

    print(f"✅ Loading train from: {TRAIN_PATH}")
    print(f"✅ Loading test  from: {TEST_PATH}")

    train_df = pd.read_csv(TRAIN_PATH)
    test_df  = pd.read_csv(TEST_PATH)

    print("Train shape:", train_df.shape)
    print("Test  shape:", test_df.shape)
    return train_df, test_df

train_df, test_df = load_data()
display(train_df.head())
display(test_df.head())
# Out:
# ✅ Loading train from: /kaggle/input/csiro-biomasszipdataset/train.csv
# ✅ Loading test  from: /kaggle/input/csiro-biomasszipdataset/test.csv
# Train shape: (1785, 9)
# Test  shape: (5, 3)
#                     sample_id              image_path Sampling_Date State  \
# 0  ID1011485656__Dry_Clover_g  train/ID1011485656.jpg      2015/9/4   Tas
# 1    ID1011485656__Dry_Dead_g  train/ID1011485656.jpg      2015/9/4   Tas
# 2   ID1011485656__Dry_Green_g  train/ID1011485656.jpg      2015/9/4   Tas
# 3   ID1011485656__Dry_Total_g  train/ID1011485656.jpg      2015/9/4   Tas
# 4         ID1011485656__GDM_g  train/ID1011485656.jpg      2015/9/4   Tas
#
#            Species  Pre_GSHH_NDVI  Height_Ave_cm   target_name   target
# 0  Ryegrass_Clover           0.62         4.6667  Dry_Clover_g   0.0000
# 1  Ryegrass_Clover           0.62         4.6667    Dry_Dead_g  31.9984
# 2  Ryegrass_Clover           0.62         4.6667   Dry_Green_g  16.2751
# 3  Ryegrass_Clover           0.62         4.6667   Dry_Total_g  48.2735
# 4  Ryegrass_Clover           0.62         4.6667         GDM_g  16.2750
#                     sample_id             image_path   target_name
# 0  ID1001187975__Dry_Clover_g  test/ID1001187975.jpg  Dry_Clover_g
# 1    ID1001187975__Dry_Dead_g  test/ID1001187975.jpg    Dry_Dead_g
# 2   ID1001187975__Dry_Green_g  test/ID1001187975.jpg   Dry_Green_g
# 3   ID1001187975__Dry_Total_g  test/ID1001187975.jpg   Dry_Total_g
# 4         ID1001187975__GDM_g  test/ID1001187975.jpg         GDM_g

# %%
# ============================================================
# 3. Image path resolution
#    - Build absolute paths for images in Kaggle environment
# ============================================================

def build_image_paths(df, dataset_roots, image_col="image_path", new_col="image_abs_path", n_check=50):
    """
    Try multiple root folders and path patterns to find which combination
    gives the most existing image files. Then apply that logic to the whole df.
    """
    if image_col not in df.columns:
        raise ValueError(f"'{image_col}' column is missing from dataframe.")

    # We'll inspect a subset for speed
    sample_df = df[[image_col]].dropna().head(n_check).copy()
    sample_paths = sample_df[image_col].tolist()

    # Candidate (root, pattern) combos
    # pattern = lambda root, p: root + something + p
    def pat1(root, p):  # join directly
        return os.path.join(root, p)
    def pat2(root, p):  # assume 'train/' (for original competition style)
        return os.path.join(root, "train", p)
    def pat3(root, p):  # assume CSV has "train/IDxxxx.jpg" already
        return os.path.join(root, p.lstrip("/"))

    patterns = [pat1, pat2, pat3]

    best_root = None
    best_pat = None
    best_count = -1

    print("🔍 Searching for best image root+pattern combination...")
    for root in dataset_roots:
        if not os.path.exists(root):
            continue
        for fn in patterns:
            cnt = 0
            for p in sample_paths:
                candidate = fn(root, p)
                if os.path.exists(candidate):
                    cnt += 1
            print(f"  Root: {root}, pattern: {fn.__name__}, exists count: {cnt}")
            if cnt > best_count:
                best_count = cnt
                best_root = root
                best_pat = fn

    if best_root is None or best_count == 0:
        print("⚠️ Could not find any valid image path combination. CNN will be skipped.")
        df[new_col] = np.nan
        return df, None, None

    print(f"\n✅ Best combination → root: {best_root}, pattern: {best_pat.__name__} "
          f"(found {best_count}/{len(sample_paths)} in sample)")

    # Apply to full df
    abs_paths = []
    for p in df[image_col].fillna(""):
        if p == "":
            abs_paths.append("")
        else:
            abs_paths.append(best_pat(best_root, p))
    df[new_col] = abs_paths

    # Show a few examples
    print("\n🔎 Example image_abs_path values:")
    print(df[new_col].head())

    # Quick existence check
    print("\n🔎 os.path.exists check for first 5 images:")
    for p in df[new_col].head():
        print(p, "->", os.path.exists(p))

    return df, best_root, best_pat


# Candidate roots you likely have in this Kaggle environment
candidate_roots = [
    "/kaggle/input/csiro-biomasszipdataset",   # your zipfile dataset root
    "/kaggle/input/csiro-biomass",          # original competition dataset
]

train_df, best_root, best_pat = build_image_paths(train_df, candidate_roots)
test_df,  _,        _        = build_image_paths(test_df, candidate_roots)
# Out:
# 🔍 Searching for best image root+pattern combination...
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat1, exists count: 50
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat2, exists count: 0
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat3, exists count: 50
#
# ✅ Best combination → root: /kaggle/input/csiro-biomasszipdataset, pattern: pat1 (found 50/50 in sample)
#
# 🔎 Example image_abs_path values:
# 0    /kaggle/input/csiro-biomasszipdataset/train/ID...
# 1    /kaggle/input/csiro-biomasszipdataset/train/ID...
# 2    /kaggle/input/csiro-biomasszipdataset/train/ID...
# 3    /kaggle/input/csiro-biomasszipdataset/train/ID...
# 4    /kaggle/input/csiro-biomasszipdataset/train/ID...
# Name: image_abs_path, dtype: object
#
# 🔎 os.path.exists check for first 5 images:
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/train/ID1011485656.jpg -> True
# 🔍 Searching for best image root+pattern combination...
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat1, exists count: 5
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat2, exists count: 0
#   Root: /kaggle/input/csiro-biomasszipdataset, pattern: pat3, exists count: 5
#
# ✅ Best combination → root: /kaggle/input/csiro-biomasszipdataset, pattern: pat1 (found 5/5 in sample)
#
# 🔎 Example image_abs_path values:
# 0    /kaggle/input/csiro-biomasszipdataset/test/ID1...
# 1    /kaggle/input/csiro-biomasszipdataset/test/ID1...
# 2    /kaggle/input/csiro-biomasszipdataset/test/ID1...
# 3    /kaggle/input/csiro-biomasszipdataset/test/ID1...
# 4    /kaggle/input/csiro-biomasszipdataset/test/ID1...
# Name: image_abs_path, dtype: object
#
# 🔎 os.path.exists check for first 5 images:
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg -> True
# /kaggle/input/csiro-biomasszipdataset/test/ID1001187975.jpg -> True

# %%
# ============================================================
# 4. CNN feature extraction with EfficientNet-B0
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("🖥 Using device:", device)

# Pretrained EfficientNet-B0
efficientnet = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
# Remove classifier head → keep global pooled features
efficientnet.classifier = torch.nn.Identity()
efficientnet.to(device)
efficientnet.eval()

# Standard ImageNet transforms
img_size = 224
cnn_transform = T.Compose([
    T.Resize((img_size, img_size)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]),
])


class CSIROImageDataset(Dataset):
    def __init__(self, df, image_col="image_abs_path", transform=None):
        self.df = df.reset_index(drop=True)
        self.image_col = image_col
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.loc[idx, self.image_col]
        exists = os.path.exists(img_path) if isinstance(img_path, str) and img_path != "" else False

        if exists:
            try:
                image = Image.open(img_path).convert("RGB")
            except Exception:
                # In case of corrupted image, use blank
                image = Image.new("RGB", (img_size, img_size), (0, 0, 0))
                exists = False
        else:
            # Missing image → use blank image
            image = Image.new("RGB", (img_size, img_size), (0, 0, 0))

        if self.transform:
            image = self.transform(image)

        return image, exists


def extract_cnn_features(df, batch_size=32, image_col="image_abs_path"):
    """
    Returns a numpy array of shape (len(df), feature_dim).
    Missing images → zero-vector.
    """
    dataset = CSIROImageDataset(df, image_col=image_col, transform=cnn_transform)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=2)

    n_samples = len(df)
    example_input = torch.randn(1, 3, img_size, img_size).to(device)
    with torch.no_grad():
        example_output = efficientnet(example_input)
    feat_dim = example_output.shape[1]
    print(f"📐 CNN feature dimension: {feat_dim}")

    features = np.zeros((n_samples, feat_dim), dtype=np.float32)

    print(f"\n🖼 Extracting CNN features for {n_samples} images...")
    idx_start = 0
    for images, exists_flags in tqdm(loader):
        bs = images.size(0)
        images = images.to(device)

        with torch.no_grad():
            feats = efficientnet(images)  # (bs, feat_dim)

        # Convert to CPU numpy
        feats = feats.cpu().numpy()

        # For missing images, we already have zeros in 'features'
        # but here we overwrite everything; we need a mask
        for i in range(bs):
            if exists_flags[i]:
                features[idx_start + i] = feats[i]
            # else: keep zeros

        idx_start += bs

    print("✅ CNN features extracted with shape:", features.shape)
    return features


# Only run CNN if we actually have a working root/pattern with some images
if best_root is not None:
    
    test_cnn_feats  = extract_cnn_features(test_df,  batch_size=32)
    train_cnn_feats = extract_cnn_features(train_df, batch_size=32)

    # Attach to dataframes
    feat_cols = [f"img_feat_{i}" for i in range(train_cnn_feats.shape[1])]
    train_img_df = pd.DataFrame(train_cnn_feats, columns=feat_cols, index=train_df.index)
    test_img_df  = pd.DataFrame(test_cnn_feats,  columns=feat_cols, index=test_df.index)

    train_df = pd.concat([train_df, train_img_df], axis=1)
    test_df  = pd.concat([test_df,  test_img_df],  axis=1)

    print("✅ Fused CNN features into train_df and test_df.")
else:
    print("⚠️ No valid image root found → proceeding with TABULAR ONLY.")
# Out:
# 🖥 Using device: cpu
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 143MB/s]
# 📐 CNN feature dimension: 1280
#
# 🖼 Extracting CNN features for 5 images...
# 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# ✅ CNN features extracted with shape: (5, 1280)
# 📐 CNN feature dimension: 1280
#
# 🖼 Extracting CNN features for 1785 images...
# 100%|██████████| 56/56 [02:06<00:00,  2.26s/it]
# ✅ CNN features extracted with shape: (1785, 1280)
# ✅ Fused CNN features into train_df and test_df.

# %%
# ============================================================
# 5. Tabular preprocessing + feature engineering
# ============================================================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer

# ---- Identify numeric columns from original training data ----
num_cols = train_df.select_dtypes(include=np.number).columns.tolist()
# Exclude target from num_cols for imputation
if "target" in num_cols:
    num_cols.remove("target")

print("Numeric columns (excluding target):", num_cols)

# ---- Concatenate train & test for consistent processing ----
train_for_concat = train_df.drop(columns=["target"], errors="ignore").copy()
full = pd.concat([train_for_concat, test_df], axis=0, ignore_index=True)

# ---- Impute numeric columns with median (fit on training data) ----
imputer = SimpleImputer(strategy="median")
imputer.fit(train_df[num_cols])
full[num_cols] = imputer.transform(full[num_cols])
print(f"✅ Imputed missing values in numerical columns: {', '.join(num_cols)} using median from training data.")

# ---- Feature Engineering: interaction term ----
if "Height_Ave_cm" in full.columns and "Pre_GSHH_NDVI" in full.columns:
    full["Height_x_NDVI"] = full["Height_Ave_cm"] * full["Pre_GSHH_NDVI"]
    print("✅ Created interaction feature 'Height_x_NDVI'")
else:
    print("⚠️ Could not create interaction feature (Height_Ave_cm or Pre_GSHH_NDVI missing).")

# ---- Polynomial features for Height_Ave_cm & Pre_GSHH_NDVI ----
poly_features_to_transform = []
if "Height_Ave_cm" in full.columns:
    poly_features_to_transform.append("Height_Ave_cm")
if "Pre_GSHH_NDVI" in full.columns:
    poly_features_to_transform.append("Pre_GSHH_NDVI")

if poly_features_to_transform:
    try:
        poly = PolynomialFeatures(degree=2, include_bias=False)
        poly_features = poly.fit_transform(full[poly_features_to_transform])
        poly_feature_names = poly.get_feature_names_out(poly_features_to_transform)
        poly_df = pd.DataFrame(poly_features, columns=poly_feature_names, index=full.index)

        # Keep only NEW polynomial terms (avoid duplicates)
        cols_to_add = [c for c in poly_df.columns if c not in poly_features_to_transform]
        poly_df = poly_df[cols_to_add]

        full = pd.concat([full, poly_df], axis=1)
        print(f"✅ Created polynomial features: {', '.join(cols_to_add)}")
    except Exception as e:
        print(f"❌ Error creating polynomial features: {e}")
else:
    print("⚠️ Skipping polynomial features; required columns missing.")
# Out:
# Numeric columns (excluding target): ['Pre_GSHH_NDVI', 'Height_Ave_cm', 'img_feat_0', 'img_feat_1', 'img_feat_2', 'img_feat_3', 'img_feat_4', 'img_feat_5', 'img_feat_6', 'img_feat_7', 'img_feat_8', 'img_feat_9', 'img_feat_10', 'img_feat_11', 'img_feat_12', 'img_feat_13', 'img_feat_14', 'img_feat_15', 'img_feat_16', 'img_feat_17', 'img_feat_18', 'img_feat_19', 'img_feat_20', 'img_feat_21', 'img_feat_22', 'img_feat_23', 'img_feat_24', 'img_feat_25', 'img_feat_26', 'img_feat_27', 'img_feat_28', 'img_feat_29', 'img_feat_30', 'img_feat_31', 'img_feat_32', 'img_feat_33', 'img_feat_34', 'img_feat_35', 'img_feat_36', 'img_feat_37', 'img_feat_38', 'img_feat_39', 'img_feat_40', 'img_feat_41', 'img_feat_42', 'img_feat_43', 'img_feat_44', 'img_feat_45', 'img_feat_46', 'img_feat_47', 'img_feat_48', 'img_feat_49', 'img_feat_50', 'img_feat_51', 'img_feat_52', 'img_feat_53', 'img_feat_54', 'img_feat_55', 'img_feat_56', 'img_feat_57', 'img_feat_58', 'img_feat_59', 'img_feat_60', 'img_feat_61', 'img_feat_62', 'img_feat_63', 'img_feat_64', 'img_feat_65', 'img_feat_66', 'img_feat_67', 'img_feat_68', 'img_feat_69', 'img_feat_70', 'img_feat_71', 'img_feat_72', 'img_feat_73', 'img_feat_74', 'img_feat_75', 'img_feat_76', 'img_feat_77', 'img_feat_78', 'img_feat_79', 'img_feat_80', 'img_feat_81', 'img_feat_82', 'img_feat_83', 'img_feat_84', 'img_feat_85', 'img_feat_86', 'img_feat_87', 'img_feat_88', 'img_feat_89', 'img_feat_90', 'img_feat_91', 'img_feat_92', 'img_feat_93', 'img_feat_94', 'img_feat_95', 'img_feat_96', 'img_feat_97', 'img_feat_98', 'img_feat_99', 'img_feat_100', 'img_feat_101', 'img_feat_102', 'img_feat_103', 'img_feat_104', 'img_feat_105', 'img_feat_106', 'img_feat_107', 'img_feat_108', 'img_feat_109', 'img_feat_110', 'img_feat_111', 'img_feat_112', 'img_feat_113', 'img_feat_114', 'img_feat_115', 'img_feat_116', 'img_feat_117', 'img_feat_118', 'img_feat_119', 'img_feat_120', 'img_feat_121', 'img_feat_122', 'img_feat_123', 'img_feat_124', 'img_feat_125', 'img_feat_126', 'img_feat_127', 'img_feat_128', 'img_feat_129', 'img_feat_130', 'img_feat_131', 'img_feat_132', 'img_feat_133', 'img_feat_134', 'img_feat_135', 'img_feat_136', 'img_feat_137', 'img_feat_138', 'img_feat_139', 'img_feat_140', 'img_feat_141', 'img_feat_142', 'img_feat_143', 'img_feat_144', 'img_feat_145', 'img_feat_146', 'img_feat_147', 'img_feat_148', 'img_feat_149', 'img_feat_150', 'img_feat_151', 'img_feat_152', 'img_feat_153', 'img_feat_154', 'img_feat_155', 'img_feat_156', 'img_feat_157', 'img_feat_158', 'img_feat_159', 'img_feat_160', 'img_feat_161', 'img_feat_162', 'img_feat_163', 'img_feat_164', 'img_feat_165', 'img_feat_166', 'img_feat_167', 'img_feat_168', 'img_feat_169', 'img_feat_170', 'img_feat_171', 'img_feat_172', 'img_feat_173', 'img_feat_174', 'img_feat_175', 'img_feat_176', 'img_feat_177', 'img_feat_178', 'img_feat_179', 'img_feat_180', 'img_feat_181', 'img_feat_182', 'img_feat_183', 'img_feat_184', 'img_feat_185', 'img_feat_186', 'img_feat_187', 'img_feat_188', 'img_feat_189', 'img_feat_190', 'img_feat_191', 'img_feat_192', 'img_feat_193', 'img_feat_194', 'img_feat_195', 'img_feat_196', 'img_feat_197', 'img_feat_198', 'img_feat_199', 'img_feat_200', 'img_feat_201', 'img_feat_202', 'img_feat_203', 'img_feat_204', 'img_feat_205', 'img_feat_206', 'img_feat_207', 'img_feat_208', 'img_feat_209', 'img_feat_210', 'img_feat_211', 'img_feat_212', 'img_feat_213', 'img_feat_214', 'img_feat_215', 'img_feat_216', 'img_feat_217', 'img_feat_218', 'img_feat_219', 'img_feat_220', 'img_feat_221', 'img_feat_222', 'img_feat_223', 'img_feat_224', 'img_feat_225', 'img_feat_226', 'img_feat_227', 'img_feat_228', 'img_feat_229', 'img_feat_230', 'img_feat_231', 'img_feat_232', 'img_feat_233', 'img_feat_234', 'img_feat_235', 'img_feat_236', 'img_feat_237', 'img_feat_238', 'img_feat_239', 'img_feat_240', 'img_feat_241', 'img_feat_242', 'img_feat_243', 'img_feat_244', 'img_feat_245', 'img_feat_246', 'img_feat_247', 'img_feat_248', 'img_feat_249', 'img_feat_250', 'img_feat_251', 'img_fe ...
# ✅ Imputed missing values in numerical columns: Pre_GSHH_NDVI, Height_Ave_cm, img_feat_0, img_feat_1, img_feat_2, img_feat_3, img_feat_4, img_feat_5, img_feat_6, img_feat_7, img_feat_8, img_feat_9, img_feat_10, img_feat_11, img_feat_12, img_feat_13, img_feat_14, img_feat_15, img_feat_16, img_feat_17, img_feat_18, img_feat_19, img_feat_20, img_feat_21, img_feat_22, img_feat_23, img_feat_24, img_feat_25, img_feat_26, img_feat_27, img_feat_28, img_feat_29, img_feat_30, img_feat_31, img_feat_32, img_feat_33, img_feat_34, img_feat_35, img_feat_36, img_feat_37, img_feat_38, img_feat_39, img_feat_40, img_feat_41, img_feat_42, img_feat_43, img_feat_44, img_feat_45, img_feat_46, img_feat_47, img_feat_48, img_feat_49, img_feat_50, img_feat_51, img_feat_52, img_feat_53, img_feat_54, img_feat_55, img_feat_56, img_feat_57, img_feat_58, img_feat_59, img_feat_60, img_feat_61, img_feat_62, img_feat_63, img_feat_64, img_feat_65, img_feat_66, img_feat_67, img_feat_68, img_feat_69, img_feat_70, img_feat_71, img_feat_72, img_feat_73, img_feat_74, img_feat_75, img_feat_76, img_feat_77, img_feat_78, img_feat_79, img_feat_80, img_feat_81, img_feat_82, img_feat_83, img_feat_84, img_feat_85, img_feat_86, img_feat_87, img_feat_88, img_feat_89, img_feat_90, img_feat_91, img_feat_92, img_feat_93, img_feat_94, img_feat_95, img_feat_96, img_feat_97, img_feat_98, img_feat_99, img_feat_100, img_feat_101, img_feat_102, img_feat_103, img_feat_104, img_feat_105, img_feat_106, img_feat_107, img_feat_108, img_feat_109, img_feat_110, img_feat_111, img_feat_112, img_feat_113, img_feat_114, img_feat_115, img_feat_116, img_feat_117, img_feat_118, img_feat_119, img_feat_120, img_feat_121, img_feat_122, img_feat_123, img_feat_124, img_feat_125, img_feat_126, img_feat_127, img_feat_128, img_feat_129, img_feat_130, img_feat_131, img_feat_132, img_feat_133, img_feat_134, img_feat_135, img_feat_136, img_feat_137, img_feat_138, img_feat_139, img_feat_140, img_feat_141, img_feat_142, img_feat_143, img_feat_144, img_feat_145, img_feat_146, img_feat_147, img_feat_148, img_feat_149, img_feat_150, img_feat_151, img_feat_152, img_feat_153, img_feat_154, img_feat_155, img_feat_156, img_feat_157, img_feat_158, img_feat_159, img_feat_160, img_feat_161, img_feat_162, img_feat_163, img_feat_164, img_feat_165, img_feat_166, img_feat_167, img_feat_168, img_feat_169, img_feat_170, img_feat_171, img_feat_172, img_feat_173, img_feat_174, img_feat_175, img_feat_176, img_feat_177, img_feat_178, img_feat_179, img_feat_180, img_feat_181, img_feat_182, img_feat_183, img_feat_184, img_feat_185, img_feat_186, img_feat_187, img_feat_188, img_feat_189, img_feat_190, img_feat_191, img_feat_192, img_feat_193, img_feat_194, img_feat_195, img_feat_196, img_feat_197, img_feat_198, img_feat_199, img_feat_200, img_feat_201, img_feat_202, img_feat_203, img_feat_204, img_feat_205, img_feat_206, img_feat_207, img_feat_208, img_feat_209, img_feat_210, img_feat_211, img_feat_212, img_feat_213, img_feat_214, img_feat_215, img_feat_216, img_feat_217, img_feat_218, img_feat_219, img_feat_220, img_feat_221, img_feat_222, img_feat_223, img_feat_224, img_feat_225, img_feat_226, img_feat_227, img_feat_228, img_feat_229, img_feat_230, img_feat_231, img_feat_232, img_feat_233, img_feat_234, img_feat_235, img_feat_236, img_feat_237, img_feat_238, img_feat_239, img_feat_240, img_feat_241, img_feat_242, img_feat_243, img_feat_244, img_feat_245, img_feat_246, img_feat_247, img_feat_248, img_feat_249, img_feat_250, img_feat_251, img_feat_252, img_feat_253, img_feat_254, img_feat_255, img_feat_256, img_feat_257, img_feat_258, img_feat_259, img_feat_260, img_feat_261, img_feat_262, img_feat_263, img_feat_264, img_feat_265, img_feat_266, img_feat_267, img_feat_268, img_feat_269, img_feat_270, img_feat_271, img_feat_272, img_feat_273, img_feat_274, img_feat_275, img_feat_276, img_feat_277, img_feat_278, img_feat_279, img_feat_280, img_feat_281, img_feat_282, img_feat_283, img_feat_284, img_feat_285, img_feat_286, img_feat_287, i ...
# ✅ Created interaction feature 'Height_x_NDVI'
# ✅ Created polynomial features: Height_Ave_cm^2, Height_Ave_cm Pre_GSHH_NDVI, Pre_GSHH_NDVI^2
# /tmp/ipykernel_47/2667440366.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   full["Height_x_NDVI"] = full["Height_Ave_cm"] * full["Pre_GSHH_NDVI"]

# %%
# ============================================================
# 6. Categorical encoding (avoiding image_path, IDs, dates)
# ============================================================

# Re-identify categoricals
cat_cols_after_fe = full.select_dtypes(include=["object", "category"]).columns.tolist()

# We explicitly DO NOT encode these (they are IDs / paths / dates)
cols_to_exclude_from_cat = ["target", "image_path", "sample_id", "Sampling_Date"]

cat_cols_for_encoding = [
    c for c in cat_cols_after_fe
    if c not in cols_to_exclude_from_cat
]

print("Categorical columns to one-hot encode:", cat_cols_for_encoding)

full_encoded = pd.get_dummies(full, columns=cat_cols_for_encoding, drop_first=False)
print("✅ One-hot encoded categorical columns.")

# ---- Split back into train & test ----
train_encoded = full_encoded.iloc[: len(train_df)].copy()
test_encoded  = full_encoded.iloc[len(train_df):].copy()

# Re-attach target
target_col = "target"
if target_col in train_df.columns:
    train_encoded[target_col] = train_df[target_col].values
else:
    raise ValueError(f"Expected '{target_col}' in original training data.")

# Drop non-feature/ID columns from X
drop_cols = [c for c in ["sample_id", "image_path", "Sampling_Date", "target_name"] if c in train_encoded.columns]
X = train_encoded.drop(columns=drop_cols + [target_col], errors="ignore")
y = train_encoded[target_col]

# Align test columns with training features
X_test_final = test_encoded.drop(columns=drop_cols, errors="ignore").reindex(columns=X.columns, fill_value=0)

# Train/validation split
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE
)

print("\nData shapes after preprocessing, CNN fusion and FE:")
print("X      :", X.shape)
print("X_train:", X_train.shape, "| X_valid:", X_valid.shape)
print("X_test :", X_test_final.shape)
print("y      :", y.shape)
# Out:
# Categorical columns to one-hot encode: ['State', 'Species', 'target_name', 'image_abs_path']
# ✅ One-hot encoded categorical columns.
#
# Data shapes after preprocessing, CNN fusion and FE:
# X      : (1785, 1668)
# X_train: (1428, 1668) | X_valid: (357, 1668)
# X_test : (5, 1668)
# y      : (1785,)

# %%
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
from sklearn.metrics import r2_score

print("\n⚡ Training Faster LightGBM model with early stopping...")

# Optional: make sure data is float32 for a small speed boost
X_train_lgb = X_train.astype("float32")
X_valid_lgb = X_valid.astype("float32")
X_full_lgb  = X.astype("float32")

lgbm_fast = LGBMRegressor(
    # lower upper bound; we want ES to stop well before this
    n_estimators=1200,
    learning_rate=0.05,      # a bit larger → fewer trees needed
    num_leaves=48,           # slightly smaller trees
    max_depth=8,             # cap depth → faster per tree
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_samples=20,
    reg_lambda=1.0,
    random_state=RANDOM_STATE,
    n_jobs=-1,
    verbose=-1,
)

lgbm_fast.fit(
    X_train_lgb, y_train,
    eval_set=[(X_valid_lgb, y_valid)],
    eval_metric="rmse",
    callbacks=[
        early_stopping(stopping_rounds=50),   # stop earlier
        log_evaluation(period=0),             # no spam in logs
    ],
)

best_iter = lgbm_fast.best_iteration_ or lgbm_fast.n_estimators
print(f"\n✅ Best iteration (fast model): {best_iter}")

valid_pred = lgbm_fast.predict(X_valid_lgb)
valid_r2 = r2_score(y_valid, valid_pred)
print("📊 Fast LightGBM Validation R2:", valid_r2)

# ---------- final_model on FULL data ----------
final_model = LGBMRegressor(
    n_estimators=best_iter,
    learning_rate=0.05,
    num_leaves=48,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_samples=20,
    reg_lambda=1.0,
    random_state=RANDOM_STATE,
    n_jobs=-1,
    verbose=-1,
)

final_model.fit(X_full_lgb, y)
print("✅ final_model (Fast LightGBM) trained on FULL training data.")
# Out:
# ⚡ Training Faster LightGBM model with early stopping...
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [1179]	valid_0's rmse: 9.90539	valid_0's l2: 98.1167
#
# ✅ Best iteration (fast model): 1179
# 📊 Fast LightGBM Validation R2: 0.8542686927583144
# ✅ final_model (Fast LightGBM) trained on FULL training data.

# %%
# ============================================================
# 7. Predict on TEST set and create submission.csv
# ============================================================

# 1. Make test features float32 like training
X_test_lgb = X_test_final.astype("float32")

# 2. Predict with the final_model
test_pred = final_model.predict(X_test_lgb)

# 3. Build submission in LONG format
#    - one row per (image, target_name)
#    - sample_id is already in test_df and matches sample_submission format
submission = pd.DataFrame({
    "sample_id": test_df["sample_id"],
    "target": test_pred.astype("float32")
})

# 4. Save with the required filename
submission.to_csv("submission.csv", index=False)

print(submission.head())
print("Submission shape:", submission.shape)
# Out:
#                     sample_id     target
# 0  ID1001187975__Dry_Clover_g   3.768795
# 1    ID1001187975__Dry_Dead_g  29.119774
# 2   ID1001187975__Dry_Green_g  23.413101
# 3   ID1001187975__Dry_Total_g  52.545574
# 4         ID1001187975__GDM_g  26.124210
# Submission shape: (5, 2)
